# %%
import pandas as pd
import os
import sys

# %%
path = os.path.abspath("../")
if(path not in sys.path):
    sys.path.append(path)

# %%
# Import data loading function
from src.data.load_data import load_raw_data

# Load raw dataset
df = load_raw_data("student_performance_dataset.csv")

# %%
from src.features.preprocessing import run_full_preprocessing

X_train, X_test, y_train, y_test = run_full_preprocessing(
    df=df,
    target_col="Pass_Fail"
)

# %%
import pandas as pd

# Example: numeric column
col = df["Study_Hours_per_Week"]

Q1 = col.quantile(0.25)
Q3 = col.quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Detect outliers
outliers = col[(col < lower) | (col > upper)]
print(outliers)
# Out:
# Series([], Name: Study_Hours_per_Week, dtype: int64)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
